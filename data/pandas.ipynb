# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import log1p
from sklearn import preprocessing
from sklearn.decomposition import PCA
from random import random
# %matplotlib inline

# %%
#read_csv
ufo = pd.read_csv('ufo.csv')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#number_of_cities
len(ufo.State)
# Out:
# 18241

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo.State.head(10) #first_10_rows
# Out:
# 0    NY
# 1    NJ
# 2    CO
# 3    KS
# 4    NY
# 5    ND
# 6    CA
# 7    MI
# 8    AK
# 9    OR
# Name: State, dtype: object

# %%
ufo['State']
# Out:
# 0        NY
# 1        NJ
# 2        CO
# 3        KS
# 4        NY
# 5        ND
# 6        CA
# 7        MI
# 8        AK
# 9        OR
# 10       CA
# 11       AL
# 12       SC
# 13       IA
# 14       MI
# 15       CA
# 16       CA
# 17       GA
# 18       TN
# 19       AK
# 20       NE
# 21       LA
# 22       LA
# 23       KY
# 24       WV
# 25       CA
# 26       WV
# 27       NM
# 28       NM
# 29       UT
#          ..
# 18211    MA
# 18212    CA
# 18213    CA
# 18214    TX
# 18215    TX
# 18216    CA
# 18217    CO
# 18218    TX
# 18219    CA
# 18220    CA
# 18221    NH
# 18222    PA
# 18223    SC
# 18224    OK
# 18225    CA
# 18226    CA
# 18227    CA
# 18228    TX
# 18229    IL
# 18230    CA
# 18231    CA
# 18232    WI
# 18233    AK
# 18234    CA
# 18235    AZ
# 18236    IL
# 18237    IA
# 18238    WI
# 18239    WI
# 18240    FL
# Name: State, Length: 18241, dtype: object

# %%
ufo['City'].head(1)
# Out:
# 0    Ithaca
# Name: City, dtype: object

# %%
ufo['City'].tail(6) #bottom 6 cities
# Out:
# 18235    Fountain Hills
# 18236        Grant Park
# 18237       Spirit Lake
# 18238       Eagle River
# 18239       Eagle River
# 18240              Ybor
# Name: City, dtype: object

# %%
ufo['Location'] = ufo.City +','+ufo.State #combine 
print(ufo['Location'])
# Out:
# 0                      Ithaca,NY
# 1                 Willingboro,NJ
# 2                     Holyoke,CO
# 3                     Abilene,KS
# 4        New York Worlds Fair,NY
# 5                 Valley City,ND
# 6                 Crater Lake,CA
# 7                        Alma,MI
# 8                     Eklutna,AK
# 9                     Hubbard,OR
# 10                    Fontana,CA
# 11                   Waterloo,AL
# 12                     Belton,SC
# 13                     Keokuk,IA
# 14                  Ludington,MI
# 15                Forest Home,CA
# 16                Los Angeles,CA
# 17                  Hapeville,GA
# 18                     Oneida,TN
# 19                 Bering Sea,AK
# 20                   Nebraska,NE
# 21                           NaN
# 22                           NaN
# 23                  Owensboro,KY
# 24                 Wilderness,WV
# 25                  San Diego,CA
# 26                 Wilderness,WV
# 27                     Clovis,NM
# ...

# %%
ufo.City.tail(6)
# Out:
# 18235    Fountain Hills
# 18236        Grant Park
# 18237       Spirit Lake
# 18238       Eagle River
# 18239       Eagle River
# 18240              Ybor
# Name: City, dtype: object

# %%
ufo.shape
# Out:
# (18241, 6)

# %%
ufo.Location
# Out:
# 0                      Ithaca,NY
# 1                 Willingboro,NJ
# 2                     Holyoke,CO
# 3                     Abilene,KS
# 4        New York Worlds Fair,NY
# 5                 Valley City,ND
# 6                 Crater Lake,CA
# 7                        Alma,MI
# 8                     Eklutna,AK
# 9                     Hubbard,OR
# 10                    Fontana,CA
# 11                   Waterloo,AL
# 12                     Belton,SC
# 13                     Keokuk,IA
# 14                  Ludington,MI
# 15                Forest Home,CA
# 16                Los Angeles,CA
# 17                  Hapeville,GA
# 18                     Oneida,TN
# 19                 Bering Sea,AK
# 20                   Nebraska,NE
# 21                           NaN
# 22                           NaN
# 23                  Owensboro,KY
# 24                 Wilderness,WV
# 25                  San Diego,CA
# 26                 Wilderness,WV
# 27                     Clovis,NM
# ...

# %%
ufo['Location']
# Out:
# 0                      Ithaca,NY
# 1                 Willingboro,NJ
# 2                     Holyoke,CO
# 3                     Abilene,KS
# 4        New York Worlds Fair,NY
# 5                 Valley City,ND
# 6                 Crater Lake,CA
# 7                        Alma,MI
# 8                     Eklutna,AK
# 9                     Hubbard,OR
# 10                    Fontana,CA
# 11                   Waterloo,AL
# 12                     Belton,SC
# 13                     Keokuk,IA
# 14                  Ludington,MI
# 15                Forest Home,CA
# 16                Los Angeles,CA
# 17                  Hapeville,GA
# 18                     Oneida,TN
# 19                 Bering Sea,AK
# 20                   Nebraska,NE
# 21                           NaN
# 22                           NaN
# 23                  Owensboro,KY
# 24                 Wilderness,WV
# 25                  San Diego,CA
# 26                 Wilderness,WV
# 27                     Clovis,NM
# ...

# %%
ufo['sta-tm'] = ufo.State +','+ufo.Time
ufo['sta-tm']
# Out:
# 0          NY,6/1/1930 22:00
# 1         NJ,6/30/1930 20:00
# 2         CO,2/15/1931 14:00
# 3          KS,6/1/1931 13:00
# 4         NY,4/18/1933 19:00
# 5         ND,9/15/1934 15:30
# 6          CA,6/15/1935 0:00
# 7          MI,7/15/1936 0:00
# 8        AK,10/15/1936 17:00
# 9          OR,6/15/1937 0:00
# 10        CA,8/15/1937 21:00
# 11         AL,6/1/1939 20:00
# 12        SC,6/30/1939 20:00
# 13          IA,7/7/1939 2:00
# 14         MI,6/1/1941 13:00
# 15         CA,7/2/1941 11:30
# 16         CA,2/25/1942 0:00
# 17         GA,6/1/1942 22:30
# 18         TN,7/15/1942 1:00
# 19        AK,4/30/1943 23:00
# 20         NE,6/1/1943 15:00
# 21         LA,8/15/1943 0:00
# 22         LA,8/15/1943 0:00
# 23       KY,10/15/1943 11:00
# 24         WV,1/1/1944 10:00
# 25         CA,1/1/1944 12:00
# 26         WV,1/1/1944 12:00
# 27         NM,4/2/1944 11:00
# 28         NM,6/1/1944 12:00
# 29        UT,6/30/1944 10:00
#                 ...
# 18211    MA,12/28/2000 18:00
# ...

# %%
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
moviez = pd.read_csv('imdb_1000.csv')
moviez
# print(moviez) #ask why it gives out diffrent outputs
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
moviez.head(20)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location              sta-tm
# 0                Ithaca,NY   NY,6/1/1930 22:00
# 1           Willingboro,NJ  NJ,6/30/1930 20:00
# 2               Holyoke,CO  CO,2/15/1931 14:00
# 3               Abilene,KS   KS,6/1/1931 13:00
# 4  New York Worlds Fair,NY  NY,4/18/1933 19:00

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ufo.shape

# %%
movies.shape
# Out:
# (979, 6)

# %%
len(movies)
# Out:
# 979

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# movies.describe(include=['object']) #return only objects

# %%
movies.star_rating
# Out:
# 0      9.3
# 1      9.2
# 2      9.1
# 3      9.0
# 4      8.9
# 5      8.9
# 6      8.9
# 7      8.9
# 8      8.9
# 9      8.9
# 10     8.8
# 11     8.8
# 12     8.8
# 13     8.8
# 14     8.8
# 15     8.7
# 16     8.7
# 17     8.7
# 18     8.7
# 19     8.7
# 20     8.7
# 21     8.7
# 22     8.7
# 23     8.7
# 24     8.7
# 25     8.6
# 26     8.6
# 27     8.6
# 28     8.6
# 29     8.6
#       ...
# 949    7.4
# 950    7.4
# 951    7.4
# 952    7.4
# 953    7.4
# 954    7.4
# 955    7.4
# 956    7.4
# 957    7.4
# 958    7.4
# 959    7.4
# 960    7.4
# 961    7.4
# 962    7.4
# 963    7.4
# 964    7.4
# 965    7.4
# 966    7.4
# 967    7.4
# 968    7.4
# 969    7.4
# 970    7.4
# 971    7.4
# 972    7.4
# 973    7.4
# 974    7.4
# 975    7.4
# 976    7.4
# 977    7.4
# 978    7.4
# Name: star_rating, Length: 979, dtype: float64

# %%
sum(movies.star_rating)
# Out:
# 7724.1000000000249

# %%
movies.star_rating.sum()
# Out:
# 7724.100000000025

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location', 'sta-tm'],
#       dtype='object')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location              sta-tm
# 0                Ithaca,NY   NY,6/1/1930 22:00
# 1           Willingboro,NJ  NJ,6/30/1930 20:00
# 2               Holyoke,CO  CO,2/15/1931 14:00
# 3               Abilene,KS   KS,6/1/1931 13:00
# 4  New York Worlds Fair,NY  NY,4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location', 'sta-tm'],
#       dtype='object')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()
# Out:
# 542                   (500) Days of Summer
# 5                             12 Angry Men
# 201                       12 Years a Slave
# 698                              127 Hours
# 110                  2001: A Space Odyssey
# 910                                   2046
# 596                               21 Grams
# 624                              25th Hour
# 708                       28 Days Later...
# 60                                3 Idiots
# 225                                 3-Iron
# 570                                    300
# 555                           3:10 to Yuma
# 427           4 Months, 3 Weeks and 2 Days
# 824                                     42
# 597                                  50/50
# 203                                  8 1/2
# 170                       A Beautiful Mind
# 941                       A Bridge Too Far
# 571                           A Bronx Tale
# 266                      A Christmas Story
# 86                      A Clockwork Orange
# ...

# %%
movies.title.sort_values(ascending=False).head()
# Out:
# 864               [Rec]
# 526                Zulu
# 615          Zombieland
# 677              Zodiac
# 955    Zero Dark Thirty
# Name: title, dtype: object

# %% [markdown]
# ##  tired keep on2mrw

# %%
movies.title.sort_values(ascending=True).head()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
# Name: title, dtype: object

# %%
movies.sort_values('title').head()
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...

# %%
movies.sort_values('title',ascending= False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
movies.sort_values(['content_rating','duration']).head()
# Out:
#      star_rating                           title content_rating      genre  \
# 713          7.6                 The Jungle Book       APPROVED  Animation
# 513          7.8  Invasion of the Body Snatchers       APPROVED     Horror
# 272          8.1                     The Killing       APPROVED      Crime
# 703          7.6                         Dracula       APPROVED     Horror
# 612          7.7              A Hard Day's Night       APPROVED     Comedy
#
#      duration                                        actors_list
# 713        78  [u'Phil Harris', u'Sebastian Cabot', u'Louis P...
# 513        80  [u'Kevin McCarthy', u'Dana Wynter', u'Larry Ga...
# 272        85  [u'Sterling Hayden', u'Coleen Gray', u'Vince E...
# 703        85  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 612        87  [u'John Lennon', u'Paul McCartney', u'George H...

# %%
booleans = []
for length in movies.duration:
    if length >= 200:
        booleans.append (True)
    else:
        booleans.append (False)

# print(booleans)

# %%
len(booleans)
# Out:
# 979

# %%
booleans[0:10]
# Out:
# [False, False, True, False, False, False, False, True, False, False]

# %%
is_long= pd.Series(booleans) # ask for .series

# %%
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
is_Long = movies.duration >= 200
movies[is_Long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
len(movies[is_Long])
# Out:
# 12

# %%
movies[movies.duration >= 200].genre #output genre with the following conditions
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movies.loc[movies.duration <= 200] #output genre with the following conditions
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# ...

# %% [markdown]
# ## use of function loc

# %%
movies.loc[movies.duration < 90,'title']
# Out:
# 29                                        City Lights
# 35                                       Modern Times
# 55                                      The Lion King
# 58                                     Paths of Glory
# 61                             Grave of the Fireflies
# 88                                            The Kid
# 98                                           Rashomon
# 117                                         Toy Story
# 131                                My Neighbor Totoro
# 174                                           Persona
# 206                                       Stand by Me
# 210                                             Laura
# 225                                            3-Iron
# 236                                         High Noon
# 258                       The Cabinet of Dr. Caligari
# 272                                       The Killing
# 283                                     Before Sunset
# ...

# %%
moviez.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ufo_rows = pd.read_csv('ufo.csv', nrows=2)
ufo_rows
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00

# %%
moviedu = []
for i in moviez.duration:
    moviedu.append(i)
         
print (moviedu)
# Out:
# [142, 175, 200, 152, 154, 96, 161, 201, 195, 139, 178, 148, 124, 142, 179, 169, 133, 207, 146, 121, 136, 130, 130, 106, 127, 116, 175, 118, 110, 87, 125, 112, 102, 107, 119, 87, 169, 115, 112, 109, 189, 110, 150, 165, 155, 137, 113, 165, 95, 151, 155, 153, 125, 130, 116, 89, 137, 117, 88, 165, 170, 89, 146, 99, 98, 116, 156, 122, 149, 134, 122, 136, 157, 123, 119, 137, 128, 120, 229, 107, 134, 103, 177, 129, 102, 216, 136, 93, 68, 189, 99, 108, 113, 181, 103, 138, 110, 129, 88, 160, 126, 91, 116, 125, 143, 93, 102, 132, 153, 183, 160, 120, 138, 140, 153, 170, 129, 81, 127, 131, 172, 115, 108, 107, 129, 156, 96, 91, 95, 162, 130, 86, 186, 151, 96, 170, 118, 161, 131, 126, 131, 129, 224, 180, 105, 117, 140, 119, 124, 130, 139, 107, 132, 117, 126, 122, 178, 238, 149, 172, 98, 116, 116, 123, 148, 123, 182, 92, 93, 100, 135, 105, 94, 140, 83, 95, 98, 143, 99, 98, 121, 163, 121, 167, 188, 121, 109, 110, 129, 127, 94, 107, 100, 117, 129, 120, 121, 133, 111, 122, 101, 134, 165, 138, 212, 154
# ...

# %%
moviedu[0:5]
# Out:
# [142, 175, 200, 152, 154]

# %%
DURE= pd.Series(moviedu)
DURE
# Out:
# 0      142
# 1      175
# 2      200
# 3      152
# 4      154
# 5       96
# 6      161
# 7      201
# 8      195
# 9      139
# 10     178
# 11     148
# 12     124
# 13     142
# 14     179
# 15     169
# 16     133
# 17     207
# 18     146
# 19     121
# 20     136
# 21     130
# 22     130
# 23     106
# 24     127
# 25     116
# 26     175
# 27     118
# 28     110
# 29      87
#       ...
# 949    103
# 950    108
# 951    105
# 952    117
# 953    102
# 954    104
# 955    157
# 956    104
# 957     98
# 958    109
# 959     96
# 960    103
# 961    114
# 962     99
# 963    118
# 964    150
# 965    105
# 966     87
# 967    136
# 968    162
# 969    109
# 970    107
# 971     90
# 972    112
# 973    126
# 974    116
# 975    118
# 976    138
# 977    114
# 978    126
# Length: 979, dtype: int64

# %%
DURE.head()
# Out:
# 0    142
# 1    175
# 2    200
# 3    152
# 4    154
# dtype: int64

# %%
DRUNK = pd.read_csv('drinks.csv')

# %%
DRUNK.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
DRUNK.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
DRUNK.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
import numpy as np
DRUNK.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
DRUNK.shape
# Out:
# (193, 6)

# %%
DRUNK.max()
# Out:
# country                              Zimbabwe
# beer_servings                             376
# spirit_servings                           438
# wine_servings                             370
# total_litres_of_pure_alcohol             14.4
# continent                       South America
# dtype: object

# %%
DRUNK.min()
# Out:
# country                         Afghanistan
# beer_servings                             0
# spirit_servings                           0
# wine_servings                             0
# total_litres_of_pure_alcohol              0
# continent                            Africa
# dtype: object

# %%
DRUNK.continent.describe()
# Out:
# count        193
# unique         6
# top       Africa
# freq          53
# Name: continent, dtype: object

# %%
DRUNK.continent.describe(include='all')
# Out:
# count        193
# unique         6
# top       Africa
# freq          53
# Name: continent, dtype: object

# %%
 DRUNK.groupby('continent').max()
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa               Zimbabwe            376              152            233
# Asia                    Yemen            247              326            123
# Europe         United Kingdom            361              373            370
# North America             USA            285              438            100
# Oceania               Vanuatu            306              254            212
# South America       Venezuela            333              302            221
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                  9.1
# Asia                                   11.5
# Europe                                 14.4
# North America                          11.9
# Oceania                                10.4
# South America                           8.3

# %%
  DRUNK.groupby('continent').agg('max')

# %%
DRUNK.groupby('continent').beer_servings.agg(['count','sum','max','min','mean','std'])

# %%
# %matplotlib inline #allow plots to appear in notebooks

# %%
 DRUNK.groupby('continent').mean().plot(kind='bar')

# %%
#value_counts

# %%
moviez.genre.value_counts()

# %%
#normalize

# %%
movies.genre.value_counts(normalize = True)

# %%
Value = []
for i in moviez.genre:
    if moviez.genre=='Drama':
        Value.append (True)
    else:
        Value.append (False)

# %%
count = 0
for i in moviez.genre:
    if(i=='Drama'):
        count+=1
print(count)

# %%
moviez.duration.plot(kind='hist')

# %%
import pandas as pd

# %%
moviez = pd.read_csv('imdb_1000.csv')

# %%
moviez.genre.value_count().plot(kind='bar')

# %%
moviez.genre

# %%
import pandas as pd
moviez= pd.read_csv('imdb_1000.csv')
moviez.genre.value_counts().plot(kind='bar')

# %%
import pandas as pd

# %%
orders= pd.read_table('chipotle.tsv')

# %%
orders.head()

# %%
#string method for pandas series accessed via string

# %%
orders.item_name.str.upper().head()

# %%
orders.choice_description.str.replace('[','').str.replace(']','')

# %%
orders.dtypes

# %%
orders.choice_description.str.replace('[/[\]]','').head()

# %%
import pandas as pd
drinks=pd.read_csv('drinks.csv')
drinks.head()

# %%
drinks['beer_servings']=drinks.beer_servings.astype(float)
drinks.dtypes

# %%
orders.item_price.str.replace('$','').astype(float).head()

# %%
 orders.item_price.describe()

# %%
orders.item_name.str.replace('Tomato','Isombe').head()

# %%
orders.head()

# %%
 orders.order_id.astype(float).head()

# %%
import pandas as pd
ufo = pd.read_csv('ufo.csv')
ufo.head()
ufo.isnull()

# %%
ufo.isnull().sum()

# %%
ufo.notnull()

# %%
ufo.shape

# %%
ufo.isnull().shape

# %%
drinks.index

# %%
drinks.columns

# %%
drinks.loc[23,'beer_servings']

# %%
import pandas as pd
drinks = pd.read_csv('drinks.csv')
drinks.set_index(inplace= True)
drinks.loc[23, 'beer_servings']

# %%
drinks.reset_index(inplace=True)

# %%
import pandas as pd
ufo = pd.read_csv('ufo.csv')
drinks.loc['Rwanda','country']
