# %% [markdown]
# # Data Visualization with Pandas

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df1['A'].hist()

# %%
# Style sheets with matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %%
plt.style.use('bmh')
df1['A'].hist()

# %%
plt.style.use('dark_background')
df1['A'].hist()

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()

# %%
plt.style.use('ggplot')

# %% [markdown]
# # Area

# %%
df2.plot.area()

# %% [markdown]
# # Bar Plots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# # Histogram

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# # Scatter plot

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B', c='C', cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# /home/mb/.local/lib/python3.6/site-packages/matplotlib/collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# # Box plots

# %%
df2.plot.box()
#With the box plots we can find the median as the purple line for each of the columns 
#Then the top quartile as the horizontal line on the box 
#Then the lower quartile as the lower horizontal line
# The range as two thick lines ontop and below the box

# %%
df2.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.460880   0.352935   0.587008   0.631597
# std     0.340793   0.301272   0.284332   0.258158
# min     0.039762   0.008948   0.103423   0.190008
# 25%     0.212334   0.179302   0.427949   0.457694
# 50%     0.371366   0.240298   0.555036   0.584144
# 75%     0.753558   0.515799   0.873619   0.837267
# max     0.937288   0.997075   0.907307   0.977680
